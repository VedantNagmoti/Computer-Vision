# %%
print("Hello")
# Out:
# Hello

# %%
import cv2
import numpy as np

# %%
image = cv2.imread('E:/python/Images for opencv/Cat image.jpg')     #Load an image using imread
cv2.imshow("Cat image : " , image)      # to display our image variable we use imshow , first parameter is title
cv2.waitKey(0)
# waitkey allows us to input information when a image window is open , by leaving it blank it just waits any key for to be pressed
cv2.destroyAllWindows()     #This closes all open windows , must be used or program may crash

# %%
print(image.shape)
# Out:
# (525, 800, 3)

# %%
print("Height of the image is " , image.shape[0])
# Out:
# Height of the image is  525

# %%
print("Width of the image is " , image.shape[1])
# Out:
# Width of the image is  800

# %%
# Saving files which are edited in opencv
cv2.imwrite('updated_image.jpg' , image)
cv2.imwrite('updated_image.png' , image)
# Out:
# True
