# %% [markdown]
# Template Matching

# %% [markdown]
# cv_TM_SQDIFF
#
# CV_TM_SQDIFF_NORMED
#
# CV_TM_CCORR
#
# CV_TM_CCORR_NORMED
#
# CV_TM_CCOEFF
#
# CV_TM_CCOEFF_NORMED

# %% [markdown]
# CHALLEGNGES = Rotation , Scaling of size , photometric changes (Contrast , brightness) , distortions from view points

# %% [markdown]
# Solution ==>> Feature extraction , detection

# %% [markdown]
# Characteristics of good features :
#
# Repeatable = they can be found in multiple images of the same scene
#
# distinctive : each feature is somewhat unique and diffrent to other features
#
# compactness and efficiency : significantly less features than no of total features
#
# locallity : feature should occupy small area of image only
