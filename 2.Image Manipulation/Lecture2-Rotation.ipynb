# %% [markdown]
# Rotation
#
# cv2.getRotationMatrix2D(rotation_center_x , rotation_center_y , angle_of_rotation , scale)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('E:/python/Images for opencv/colors.jpg')
# cv2.imshow('image', image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
height , width = image.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D([height/2 , width/2] , 60 , 0.5)
rotated_image = cv2.warpAffine(image , rotation_matrix , (width , height))
plt.imshow(rotated_image)

# %% [markdown]
# For rotating the image 90 degrees and without the black empty spaces around the image i.e : 100 % image
#
# Rotating completely 90 degrees

# %%
transpose = cv2.transpose(image)
plt.imshow(transpose)
